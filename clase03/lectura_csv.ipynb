# %%
import csv
# declaramos lista vacia
headers = None
data = []
# abrimos archivos test.csv en modo lectura ("r") lo asignamos a 
# la variable csvfile
with open("./data/python_met.csv", "r") as csvfile:
    # leemos el contenido de csvfile y lo parseamos como csv
    # csv = comma separated value
    csv_reader = csv.reader(csvfile)
    # recorremos todas la filas
    for row_number, row in enumerate(csv_reader):
        # las agregamos a la lista data
        if row_number == 0:
            headers = row
        else:
            data.append(row)

# %%
headers
# Out:
# ['Nombre',
#  'Apellido',
#  'Dirección de correo electrónico',
#  'Conocimientos en Programación y Lógica',
#  'Examen',
#  'Estado',
#  'Github']

# %%
data
# Out:
# [['Anahi',
#   'Gaetan',
#   'anahigaetan@hotmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'anagaetan'],
#  ['Andrea',
#   'Otamendi',
#   'andreotamendi@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'AndreOtamendi'],
#  ['Blanca',
#   'Ayala',
#   'ayalaluquez@riseup.net',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'ayalaluquez'],
#  ['Carolina',
#   'Bustos',
#   'bsts.carolina@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'carobsts'],
#  ['florencia',
#   'espeche',
#   'flor.espeche@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'florencia-espeche'],
#  ['Guadalupe Ailen',
#   'Padin Rojas',
#   'guadapadinrojas@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'GPRNomade'],
#  ['Alejandra Jesica',
#   'Peñaloza',
#   'penalozajesica@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'jessiepenaloza'],
#  ['Candela',
#   'Spitale',
#   'candela.fiume@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'Knd9'],
#  ['Patricia',
#   'Del castillo',
#   'patt8i@hotmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'magogaflo'],
#  ['María de los Ángeles',
#   'Oroz',
#   'angelesoroz@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'maoroz'],
#  ['Maylen',
#   'Cuevas',
#   'maylen_cuevas@hotmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'MayCuevas'],
#  ['Mirna',
#   'Díaz Luján',
#   'mirnaedl@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'mirnaedl'],
#  ['Noelia',
#   'Perez',
#   'noe.perez.122@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'noeemperez'],
#  ['Paula',
#   'Sosa',
#   'sosa.pau@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'Pau977'],
#  ['Rocío',
#   'Amaranto',
#   'roamaranto73@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'rocioo73'],
#  ['Romina ',
#   'Carrazana',
#   'rominacarrazana@hotmail.com',
#   'basico',
#   '',
#   '',
#   'romicarrazana'],
#  ['Romina Sol',
#   'Haag',
#   'rominasolhaag@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'RominaSolHaag'],
#  ['Roxana',
#   'Hernández',
#   'roxanahernandez326@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   'RoxanaHernandez'],
#  ['Sabrina',
#   'Pescetti',
#   'sabrinapescetti@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'sabrinetti'],
#  ['Soledad',
#   'Cortéz',
#   'soledadcortez@hotmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   'soledadcortez'],
#  ['Yanina', 'Iberra', 'yaninaiberra@gmail.com', 'Avanzado', '', '', ''],
#  ['Tatiana',
#   'Villa',
#   'tatianavilla2293@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   ''],
#  ['Rosangela',
#   'Labrador',
#   'rossy.code@gmail.com',
#   'Básico',
#   'realizado ',
#   'confirmada',
#   ''],
#  ['Belen', 'Diaz', 'yaninabelendiaz@outlook.com', 'Básico', '', '', ''],
#  ['Eugenia', 'Maldonado', 'm.eugemaldonado@gmail.com', 'Básico', '', '', ''],
#  ['Lorena', 'Vivas', 'alorenav@gmail.com', 'Básico', '', '', ''],
#  ['Pamela',
#   'Acosta',
#   'paaacosta2016@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   ''],
#  ['Ashley Denise',
#   'Quezada Montengro',
#   'ashquezada30@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   ''],
#  ['Micaela',
#   'Fuentes',
#   'micaela_fuentes@hotmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   ''],
#  ['Viviana',
#   'Martin',
#   'viviana.lorena.martin@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   ''],
#  ['Carla',
#   'Capocci',
#   'carla.a.capocci@gmail.com',
#   'Intermedio',
#   'realizado ',
#   'confirmada',
#   ''],
#  ['Jeanette Candela',
#   'Peralta Arias',
#   'jeanettecandela@gmail.com',
#   'Intermedio',
#   '',
#   '',
#   ''],
#  ['Maria Emilia',
#   'del Sacramento',
#   'edelsacrmanento@gmail.com',
#   'Intermedio',
#   '',
#   '',
#   ''],
#  ['Verónica',
#   'Bornancini',
#   'verobornancini@gmail.com',
#   'Intermedio',
#   '',
#   '',
#   ''],
#  ['Emiliano',
#   'Policardo',
#   'emilianopolicardo@gmail.com',
#   'Intermedio',
#   '',
#   '',
#   ''],
#  ['Eliana Jimena',
#   'Palmero',
#   'jime_389@hotmail.com',
#   '',
#   '',
#   'confirmada',
#   '']]

# %% [markdown]
# Tarea:
# =====
#
# 1- Se debe crear clase estudiante que en su constructor tome como parametro:
# * name
# * lastname
# * email
# * conocimientos_de_programacion
#
#
# 2- Leer csv y generar instancias de estudiante a partir de las columnas leidas
